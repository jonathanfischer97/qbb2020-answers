# %% [markdown]
# Load Package

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Work with Lists

# %%
x = [1, 2, 3, 4, 5]
x
# Out:
# [1, 2, 3, 4, 5]

# %%
type( x )
# Out:
# list

# %%
len(x)
# Out:
# 5

# %%
x[1]
# Out:
# 2

# %% [markdown]
# Plot a Line

# %%
y = [1, 4, 9, 16, 25]

# %%
fig, ax = plt.subplots()
ax.plot( x, y )
plt.show()

# %% [markdown]
# Plot multiple series

# %%
x2 = [2, 4, 6]
y2 = [8, 64, 216]

# %% [markdown]
# Annotate plot

# %%
fig, ax = plt.subplots()
ax.plot( x, y )
ax.plot( x2, y2, '+' )
plt.show()

# %% [markdown]
# Subplot

# %%
fig, ax = plt.subplots()
ax.plot( x, y, label="x^2" )
ax.plot( x2, y2, '+', label="x^3" )
ax.set_title( "Polynomials" )
ax.set_xlabel( "x" )
ax.set_ylabel( "f(x)" )
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots( nrows=2, sharex = True, sharey = True )
ax[0].plot( x, y, '.' )
ax[1].plot( x2, y2 )
plt.show()

# %% [markdown]
# Exercise 1: Share axes

# %%
fig, ax = plt.subplots( nrows=2, sharex = True, sharey = True )
ax[0].plot( x, y, '.' )
ax[1].plot( x2, y2 )
plt.show()

# %% [markdown]
# Exercise 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bed_columns = ["chr", "start", "end"]
bed_columns
# Out:
# ['chr', 'start', 'end']

# %%
df_k4 = pd.read_table( "../../qbb2020/data/K4me3.bed",
                        names=bed_columns)
df_k4
# Out:
#      chr     start       end
# 0     3L  15823270  15830715
# 1     2R  11451787  11459612
# 2     3R  21665759  21673392
# 3     2R  20324929  20331038
# 4     3R  19859679  19864278
# ...   ..       ...       ...
# 3825  3R    565835    566082
# 3826  2L  10439373  10442085
# 3827  3R   4477321   4479529
# 3828  3L    711347    711871
# 3829  2L   6792695   6795077
#
# [3830 rows x 3 columns]

# %%
df_k4.shape
# Out:
# (3830, 3)

# %%
df_k4.loc[:, "width"] = df_k4.loc[:,"end"] - df_k4.loc[:,"start"]
df_k4
# Out:
#      chr     start       end  width
# 0     3L  15823270  15830715   7445
# 1     2R  11451787  11459612   7825
# 2     3R  21665759  21673392   7633
# 3     2R  20324929  20331038   6109
# 4     3R  19859679  19864278   4599
# ...   ..       ...       ...    ...
# 3825  3R    565835    566082    247
# 3826  2L  10439373  10442085   2712
# 3827  3R   4477321   4479529   2208
# 3828  3L    711347    711871    524
# 3829  2L   6792695   6795077   2382
#
# [3830 rows x 4 columns]

# %%
fig, ax = plt.subplots()
ax.hist( df_k4.loc[:,"width"])

plt.show()

# %%
#extracting chr column 
chr_k4_regions = pd.Index(df_k4.loc[:, "chr"])

#counting frequencies in series
chr_k4 = chr_k4_regions.value_counts()
print(chr_k4)

sorted_chr_k4 = chr_k4.sort_index()
print(sorted_chr_k4)



fig, ax = plt.subplots()
ax.set_title("K4me3 Region Counts")
ax.set_ylabel("Counts")
ax.set_xlabel("Regions")
ax.bar(sorted_chr_k4.index[:-2], sorted_chr_k4[:-2] )
plt.show()
# Out:
# 3R                     897
# 2R                     799
# 3L                     773
# 2L                     713
# X                      580
# 4                       65
# Y                        2
# Y_CP007111v1_random      1
# Name: chr, dtype: int64
# 2L                     713
# 2R                     799
# 3L                     773
# 3R                     897
# 4                       65
# X                      580
# Y                        2
# Y_CP007111v1_random      1
# Name: chr, dtype: int64

# %% [markdown]
# Plots for K9 and K27

# %% [markdown]
# Extracting bed files for K9/K27

# %%
df_k9 = pd.read_table( "../../qbb2020/data/K9me3.bed",
                        names=bed_columns)
print(df_k9)

df_k27 = pd.read_table( "../../qbb2020/data/K27me3.bed",
                        names=bed_columns)
print(df_k27)
# Out:
#     chr     start       end
# 0    2L      5031     13131
# 1    2L    356567    382831
# 2    2L    582167    609431
# 3    2L    975967    996567
# 4    2L   1667067   1687931
# ..   ..       ...       ...
# 291   X  22708532  22720332
# 292   X  22865032  22882596
# 293   X  22981432  23009896
# 294   X  23156000  23204164
# 295   Y    650514   1655192
#
# [296 rows x 3 columns]
#     chr     start       end
# 0    2L      5037      9637
# 1    2L    322173    326237
# 2    2L    365873    398837
# 3    2L    498973    547373
# 4    2L    579973    608037
# ..   ..       ...       ...
# 426   X  20310691  20388555
# 427   X  20534591  20759055
# 428   X  20824191  20835255
# 429   X  20924791  20953755
# 430   X  21464155  21496991
#
# [431 rows x 3 columns]

# %% [markdown]
# Calculating width for chromosome regions

# %%
df_k9.loc[:, "width"] = df_k9.loc[:,"end"] - df_k9.loc[:,"start"]
df_k9
# Out:
#     chr     start       end    width
# 0    2L      5031     13131     8100
# 1    2L    356567    382831    26264
# 2    2L    582167    609431    27264
# 3    2L    975967    996567    20600
# 4    2L   1667067   1687931    20864
# ..   ..       ...       ...      ...
# 291   X  22708532  22720332    11800
# 292   X  22865032  22882596    17564
# 293   X  22981432  23009896    28464
# 294   X  23156000  23204164    48164
# 295   Y    650514   1655192  1004678
#
# [296 rows x 4 columns]

# %%
df_k27.loc[:, "width"] = df_k27.loc[:,"end"] - df_k27.loc[:,"start"]
df_k27
# Out:
#     chr     start       end   width
# 0    2L      5037      9637    4600
# 1    2L    322173    326237    4064
# 2    2L    365873    398837   32964
# 3    2L    498973    547373   48400
# 4    2L    579973    608037   28064
# ..   ..       ...       ...     ...
# 426   X  20310691  20388555   77864
# 427   X  20534591  20759055  224464
# 428   X  20824191  20835255   11064
# 429   X  20924791  20953755   28964
# 430   X  21464155  21496991   32836
#
# [431 rows x 4 columns]

# %%
#extracting chr_k9 column 
chr_k9_regions = pd.Index(df_k9.loc[:, "chr"])

#counting frequencies in series
chr_k9 = chr_k9_regions.value_counts()
print(chr_k9)

sorted_chr_k9 = chr_k9.sort_index()
print(sorted_chr_k9)



fig, ax = plt.subplots()
ax.set_title("K9me3 Region Counts")
ax.set_ylabel("Counts")
ax.set_xlabel("Regions")
ax.bar(sorted_chr_k9.index[:-2], sorted_chr_k9[:-2] )
plt.show()
# Out:
# 3L                     67
# X                      61
# 2L                     53
# 3R                     51
# 2R                     50
# 4                      11
# Y                       2
# Y_DS483690v1_random     1
# Name: chr, dtype: int64
# 2L                     53
# 2R                     50
# 3L                     67
# 3R                     51
# 4                      11
# X                      61
# Y                       2
# Y_DS483690v1_random     1
# Name: chr, dtype: int64

# %%
#extracting chr_k27 column 
chr_k27_regions = pd.Index(df_k27.loc[:, "chr"])

#counting frequencies in series
chr_k27 = chr_k27_regions.value_counts()
print(chr_k27)

sorted_chr_k27 = chr_k27.sort_index()
print(sorted_chr_k27)
# Out:
# 2R               102
# 3R                90
# 3L                89
# 2L                80
# X                 64
# 4                  5
# Un_CP007080v1      1
# Name: chr, dtype: int64
# 2L                80
# 2R               102
# 3L                89
# 3R                90
# 4                  5
# Un_CP007080v1      1
# X                 64
# Name: chr, dtype: int64

# %% [markdown]
# Exercise 3: Creating chromosome distrubtion figure with 3 subplots

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize = (23, 6))
fig.suptitle("Chromosome Distributions")

#k4me3
ax1.bar(sorted_chr_k4.index, sorted_chr_k4 )
ax1.set_title("K4me3 Region Counts")
ax1.set_ylabel("Counts")
ax1.set_xlabel("Regions")

#k9me3
ax2.bar(sorted_chr_k9.index, sorted_chr_k9 )
ax2.set_title("K9me3 Region Counts")
ax2.set_ylabel("Counts")
ax2.set_xlabel("Regions")

#k27me3
ax3.bar(sorted_chr_k27.index, sorted_chr_k27 )
ax3.set_title("K27me3 Region Counts")
ax3.set_ylabel("Counts")
ax3.set_xlabel("Regions")
plt.show()

# %%
Exercise 4: Creating width distribution figure

# %%
fig,(ax1, ax2, ax3) = plt.subplots(ncols = 3, figsize = (21, 6))
fig.suptitle("Width Distribution")

ax1.hist(df_k4.loc[:, "width"])
ax1.set_title("K4me3 Width Ditribution")
ax1.set_ylabel("Region Counts")
ax1.set_xlabel("Region Length")

ax2.hist(df_k9.loc[:, "width"])
ax2.set_title("K9me3 Width Distribution")
ax2.set_ylabel("Region Counts")
ax2.set_xlabel("Region Length")

ax3.hist(df_k27.loc[:, "width"])
ax3.set_title("K27me3 Width Distribution")
ax3.set_ylabel("Region Counts")
ax3.set_xlabel("Region Length")
plt.show()
